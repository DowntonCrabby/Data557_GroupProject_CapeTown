# %%
import csv
import pandas as pd

# %%
long = pd.read_csv("/Users/sophie/Desktop/UWash/Data 557/Data557_GroupProject_CapeTown/Code/Question2/promoted_faculty_longitudinal.csv")
long.head()
# Out:
#    case  id sex  deg  yrdeg field  startyr  year   rank  admin  salary  \
# 0    40  10   M  PhD     68  Arts       80    80  Assoc      0  3250.0
# 1    41  10   M  PhD     68  Arts       80    81  Assoc      0  3671.0
# 2    42  10   M  PhD     68  Arts       80    82  Assoc      0  3831.0
# 3    43  10   M  PhD     68  Arts       80    83  Assoc      0  4042.0
# 4    44  10   M  PhD     68  Arts       80    84  Assoc      0  4317.0
#
#    first_associate_year  promotion_year
# 0                    80              93
# 1                    80              93
# 2                    80              93
# 3                    80              93
# 4                    80              93

# %%
summ = pd.read_csv("/Users/sophie/Desktop/UWash/Data 557/Data557_GroupProject_CapeTown/Code/Question2/promoted_faculty_summary.csv")
summ.head()
# Out:
#    id sex  deg  yrdeg  field  startyr  first_associate_year  ever_promoted  \
# 0  10   M  PhD     68   Arts       80                    80              1
# 1  13   M  PhD     68   Prof       69                    76              1
# 2  14   M  PhD     79  Other       92                    92              1
# 3  16   M  PhD     73  Other       79                    82              1
# 4  17   M  PhD     72  Other       72                    77              1
#
#   associate_cohort_bin  assoc_year_centered  promotion_year
# 0             (75, 80]            -4.300813              93
# 1             (75, 80]            -8.300813              82
# 2             (90, 95]             7.699187              94
# 3             (80, 85]            -2.300813              89
# 4             (75, 80]            -7.300813              83

# %%
event = pd.read_csv("/Users/sophie/Desktop/UWash/Data 557/Data557_GroupProject_CapeTown/Code/Question2/promotion_event_dataset.csv")
event
# Out:
#        id sex    deg  yrdeg  field  startyr  first_associate_year  \
# 0      10   M    PhD     68   Arts       80                    80
# 1      13   M    PhD     68   Prof       69                    76
# 2      14   M    PhD     79  Other       92                    92
# 3      16   M    PhD     73  Other       79                    82
# 4      17   M    PhD     72  Other       72                    77
# ..    ...  ..    ...    ...    ...      ...                   ...
# 542  1757   F  Other     69  Other       82                    82
# 543  1764   M  Other     71  Other       77                    84
# 544  1765   M  Other     55   Arts       68                    76
# 545  1766   M  Other     55   Arts       68                    76
# 546  1770   M  Other     51  Other       64                    76
#
#      ever_promoted associate_cohort_bin  assoc_year_centered  promotion_year  \
# 0                1             (75, 80]            -4.300813              93
# ...

# %%
df = pd.read_csv("/Users/sophie/Desktop/UWash/Data 557/Data557_GroupProject_CapeTown/Code/Question2/promoted_faculty_dataset.csv")
df.head()
# Out:
#    id sex  deg  yrdeg  field  startyr  first_associate_year  ever_promoted  \
# 0  10   M  PhD     68   Arts       80                    80              1
# 1  13   M  PhD     68   Prof       69                    76              1
# 2  14   M  PhD     79  Other       92                    92              1
# 3  16   M  PhD     73  Other       79                    82              1
# 4  17   M  PhD     72  Other       72                    77              1
#
#   associate_cohort_bin  assoc_year_centered  promotion_year  \
# 0             (75, 80]            -4.300813              93
# 1             (75, 80]            -8.300813              82
# 2             (90, 95]             7.699187              94
# 3             (80, 85]            -2.300813              89
# 4             (75, 80]            -7.300813              83
#
#    salary_at_promotion
# 0               7180.0
# 1               3322.0
# 2               9025.0
# 3               5290.0
# 4               2994.0
